# %%
import sys
import os
import matplotlib.pyplot as plt
% matplotlib notebook
import pickle
# Import class
parent_dir = os.path.dirname(os.getcwd())
class_dir = os.path.join(parent_dir, 'Scripts')
sys.path.insert(0, class_dir)
import NBAStats
import datetime as dt

# %%
parent_dir = os.path.dirname(os.getcwd())
stats_file = os.path.join(parent_dir, 'Data', 'nba_stats.pickle')
print(stats_file)
nba_stats = pickle.load(open(stats_file, 'rb'))
# Out:
# C:\Users\johnn\Desktop\sports_betting\Data\nba_stats.pickle

# %%
nba_stats.get_boxscores()['0021700133']
# Out:
#        GAME_ID     TEAM_ID TEAM_ABBREVIATION    TEAM_CITY  PLAYER_ID  \
# 0   0021700133  1610612740               NOP  New Orleans     201967
# 1   0021700133  1610612740               NOP  New Orleans     203076
# 2   0021700133  1610612740               NOP  New Orleans     202326
# 3   0021700133  1610612740               NOP  New Orleans     202734
# 4   0021700133  1610612740               NOP  New Orleans     201950
# 5   0021700133  1610612740               NOP  New Orleans       2749
# 6   0021700133  1610612740               NOP  New Orleans       2754
# 7   0021700133  1610612740               NOP  New Orleans     203121
# 8   0021700133  1610612740               NOP  New Orleans     203546
# 9   0021700133  1610612740               NOP  New Orleans    1627767
# 10  0021700133  1610612740               NOP  New Orleans       2746
# 11  0021700133  1610612741               CHI      Chicago    1628021
# 12  0021700133  1610612741               CHI      Chicago    1628374
# ...

# %%
nba_stats._get_game_info(dt.date(2017, 11, 4), '2017-18', 'Regular Season', nba_stats.REQUEST_HEADERS)
# Out:
# Accessing stats.nba.com for games on 2017-11-04.....Successful
#   SEASON_YEAR     TEAM_ID TEAM_ABBREVIATION     GAME_ID            GAME_DATE  \
# 0     2017-18  1610612744               GSW  0021700135  2017-11-04T00:00:00
# 1     2017-18  1610612750               MIN  0021700134  2017-11-04T00:00:00
# 2     2017-18  1610612763               MEM  0021700131  2017-11-04T00:00:00
# 3     2017-18  1610612765               DET  0021700132  2017-11-04T00:00:00
# 4     2017-18  1610612740               NOP  0021700133  2017-11-04T00:00:00
# 5     2017-18  1610612741               CHI  0021700133  2017-11-04T00:00:00
# 6     2017-18  1610612746               LAC  0021700131  2017-11-04T00:00:00
# 7     2017-18  1610612758               SAC  0021700132  2017-11-04T00:00:00
# 8     2017-18  1610612742               DAL  0021700134  2017-11-04T00:00:00
# 9     2017-18  1610612743               DEN  0021700135  2017-11-04T00:00:00
#
# ...

# %%
df_sc30 = nba_stats.get_player_stats()[nba_stats.get_player_name_id_dict()['Stephen Curry']]
df_sc30.plot(y='PTS')
# Out:
# <img src="data:image/png;base64,..." width="640">
