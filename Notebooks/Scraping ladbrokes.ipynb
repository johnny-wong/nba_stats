# %%
import requests
from bs4 import BeautifulSoup

# %%
home_page = 'https://www.ladbrokes.com.au/sports/basketball/64472144-basketball-usa-nba/'
r = requests.get(home_page)

assert r.status_code == 200

# %%
r.headers['content-type']
# Out:
# 'text/html; charset=UTF-8'

# %%
soup = BeautifulSoup(r.text, 'lxml')
# markets = soup.find_all('div', attrs={'class':'basketball'})
test = soup.find_all('div')

for div in test:
    try:
        print(div['class'])
    except:
        pass
# Out:
# ['betslip-slide']
# ['betslip-slide-inner']
# ['device-banner']
# ['jswarning']
# ['inner']
# ['security']
# ['time']
# ['main-header']
# ['inner']
# ['main-nav']
# ['inner']
# ['but_betslip', 'betslip-show']
# ['contentinner']
# ['sideNav']
# ['sideNav']
# ['sideNav']
# ['sideNav']
# ['basketball']
# ['leaderboard-signup', 'user-logged-out', 'is-geoblocked']
# ['inner']
# ['slim-leaderboard', 'user-logged-out', 'is-geoblocked']
# ['clear']
# ['clear']
# ['main-footer-wrapper']
# ['main-footer']
# ['footer-top-row', 'clear', 'clearfix']
# ['one-fourth', 'last-col']
# ['siteinfo']
# ['box', 'one-fourth', 'marg-right', 'sitelinks']
# ['box', 'one-fourth', 'marg-right', 'betting-operator']
# ['icons', 'nrl']
# ['icons', 'ca']
# ['icons', 'afl']
# ['icons', 'ta']
# ['icons', 'aru']
# ['icons', 'pgaa']
# ['clear']
# ['box', 'one-fourth', 'marg-right', 'betting-operator']
# ['icons', 'mrc']
# ['icons', 'lbp']
# ['icons', 'morc']
# ['icons', 'clfd']
# ['icons', 'moonee']
# ...

# %%
soup.prettify()
# Out:
# '<!DOCTYPE html>\n<html xmlns="http://www.w3.org/1999/html">\n <head>\n  <meta content="IE=Edge,chrome=IE6" http-equiv="X-UA-Compatible"/>\n  <title>\n   Sports Betting - Basketball - Bet on Basketball USA - NBA - Ladbrokes.com.au\n  </title>\n  <meta content="AU" name="geo.country"/>\n  <meta content="" name="description"/>\n  <meta content="" name="keywords"/>\n  <meta charset="utf-8"/>\n  <script type="text/javascript">\n   (window.NREUM||(NREUM={})).loader_config={xpid:"UwAGVlRbGwcGVFRRDwMF"};window.NREUM||(NREUM={}),__nr_require=function(t,n,e){function r(e){if(!n[e]){var o=n[e]={exports:{}};t[e][0].call(o.exports,function(n){var o=t[e][1][n];return r(o||n)},o,o.exports)}return n[e].exports}if("function"==typeof __nr_require)return __nr_require;for(var o=0;o<e.length;o++)r(e[o]);return r}({1:[function(t,n,e){function r(t){try{s.console&&console.log(t)}catch(n){}}var o,i=t("ee"),a=t(16),s={};try{o=localStorage.getItem("__nr_flags").split(","),console&&"function"==typeof console.l
# ...
