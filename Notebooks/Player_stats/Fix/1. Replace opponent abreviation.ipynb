# %% [markdown]
# # Replace team abbreviations with proper abbreviations
# Related to \#1, bug in code recorded incorrect team abbreviations

# %%
import sys
import os
import matplotlib.pyplot as plt
% matplotlib notebook
import pickle
# Import class
parent_dir = os.path.dirname(os.path.dirname(os.getcwd()))
class_dir = os.path.join(parent_dir, 'Scripts')
sys.path.insert(0, class_dir)
import NBAStats
import datetime as dt

# %%
stats_file = os.path.join(parent_dir, 'Data', 'nba_stats.pickle')
print(stats_file)
nba_stats = pickle.load(open(stats_file, 'rb'))
# Out:
# C:\Users\johnn\Desktop\github\nba_stats\Data\nba_stats.pickle

# %%
dict_player_stats = nba_stats.get_player_stats()
games = nba_stats.get_games().sort_values(by='GAME_DATE')
df_player = dict_player_stats[203967]

# %%
games.head()
# Out:
#   SEASON_YEAR     TEAM_ID TEAM_ABBREVIATION     GAME_ID            GAME_DATE  \
# 0     2011-12  1610612759               SAS  0041100141  2012-04-29T00:00:00
# 2     2011-12  1610612737               ATL  0041100131  2012-04-29T00:00:00
# 3     2011-12  1610612746               LAC  0041100171  2012-04-29T00:00:00
# 4     2011-12  1610612763               MEM  0041100171  2012-04-29T00:00:00
# 5     2011-12  1610612738               BOS  0041100131  2012-04-29T00:00:00
#
#        MATCHUP WL  PTS HOME_AWAY OPP_TEAM_ABBREVIATION OPP_TEAM_ID OPP_PTS
# 0  SAS vs. UTA  W  106      HOME                   UTA  1610612762      91
# 2  ATL vs. BOS  W   83      HOME                   BOS  1610612738      74
# 3    LAC @ MEM  W   99      AWAY                   MEM  1610612763      98
# 4  MEM vs. LAC  L   98      HOME                   LAC  1610612746      99
# 5    BOS @ ATL  L   74      AWAY                   ATL  1610612737      83

# %%
df_player.head()
# Out:
#                GAME_ID     TEAM_ID TEAM_ABBREVIATION     TEAM_CITY PLAYER_ID  \
# Date
# 2018-10-16  0021800001  1610612755               PHI  Philadelphia    203967
# 2018-10-18  0021800014  1610612755               PHI  Philadelphia    203967
# 2018-10-20  0021800029  1610612755               PHI  Philadelphia    203967
# 2018-10-23  0021800049  1610612755               PHI  Philadelphia    203967
# 2018-10-24  0021800059  1610612755               PHI  Philadelphia    203967
#
#             PLAYER_NAME START_POSITION COMMENT    MIN FGM     ...     AST STL  \
# Date                                                          ...
# 2018-10-16  Dario Saric              F          22:54   3     ...       1   0
# 2018-10-18  Dario Saric              F          28:20   4     ...       3   1
# 2018-10-20  Dario Saric              F          37:34   4     ...       5   1
# 2018-10-23  Dario Saric              F          37:42   5     ...       5   1
# 2018-10-24  Dario Saric              F          33:30   6     ...       0   0
#
#            BLK TO PF PTS PLUS_MINUS HOME_AWAY OPP_TEAM_ABBREVIATION  \
# Date
# 2018-10-16   0  3  5   6         -4      AWAY                   BOS
# 2018-10-18   0  3  2  13          9      HOME                   CHI
# 2018-10-20   1  2  3  13        -11      HOME                   PHI
# 2018-10-23   1  1  4  14          1      AWAY                   DET
# 2018-10-24   0  1  3  15        -16      AWAY                   PHI
#
#            OPP_TEAM_ID
# Date
# 2018-10-16  1610612738
# 2018-10-18  1610612741
# 2018-10-20  1610612753
# 2018-10-23  1610612765
# 2018-10-24  1610612749
#
# [5 rows x 31 columns]

# %% [markdown]
# ### Create mapping
# We need a mapping from TEAM_ID to TEAM_ABBREVIATION

# %%
df_team_id_abb = games[['GAME_DATE', 'TEAM_ID', 'TEAM_ABBREVIATION']]
df_team_id_abb_unique = df_team_id_abb.drop_duplicates(subset='TEAM_ABBREVIATION').sort_values(by=['TEAM_ID', 
                                                                                                  'GAME_DATE'])
# Convert GAME_DATE from str to dt.date
df_team_id_abb_unique.GAME_DATE = df_team_id_abb_unique.GAME_DATE.apply(
    lambda date: dt.datetime.strptime(date[:10], '%Y-%m-%d'))

# %%
df_team_id_abb_unique.head(6)
# Out:
#     GAME_DATE     TEAM_ID TEAM_ABBREVIATION
# 2  2012-04-29  1610612737               ATL
# 5  2012-04-29  1610612738               BOS
# 14 2015-01-02  1610612739               CLE
# 21 2015-01-02  1610612740               NOP
# 0  2015-01-01  1610612741               CHI
# 19 2015-01-02  1610612742               DAL

# %% [markdown]
# ### Create function to map
# Create a function to run over all entries in player stats

# %%
def team_id_to_abb(team_id, mapping, date):
    df_team_abbs = mapping[(mapping.TEAM_ID == team_id) &
                      (mapping.GAME_DATE <= date)]
    most_rec_date = max(df_team_abbs.GAME_DATE)
    team_abb = df_team_abbs[df_team_abbs.GAME_DATE == most_rec_date]['TEAM_ABBREVIATION'].iloc[0]
    return team_abb

# %%
team_id_to_abb(1610612753, df_team_id_abb_unique, dt.date(2018, 10, 20))
# Out:
# 'ORL'

# %% [markdown]
# ### Create function to apply
# Takes in a row of player df and returns the opponent's team abbreviation

# %%
def row_to_abb(row):
    date = row.name
    opp_team_id = row.OPP_TEAM_ID
    opp_team_abb = team_id_to_abb(opp_team_id, df_team_id_abb_unique, date)
    return opp_team_abb

# %%
df_player.OPP_TEAM_ABBREVIATION = df_player.apply(row_to_abb, axis=1)
df_player.head()
# Out:
#                GAME_ID     TEAM_ID TEAM_ABBREVIATION     TEAM_CITY PLAYER_ID  \
# Date
# 2018-10-16  0021800001  1610612755               PHI  Philadelphia    203967
# 2018-10-18  0021800014  1610612755               PHI  Philadelphia    203967
# 2018-10-20  0021800029  1610612755               PHI  Philadelphia    203967
# 2018-10-23  0021800049  1610612755               PHI  Philadelphia    203967
# 2018-10-24  0021800059  1610612755               PHI  Philadelphia    203967
#
#             PLAYER_NAME START_POSITION COMMENT    MIN FGM     ...     AST STL  \
# Date                                                          ...
# 2018-10-16  Dario Saric              F          22:54   3     ...       1   0
# 2018-10-18  Dario Saric              F          28:20   4     ...       3   1
# 2018-10-20  Dario Saric              F          37:34   4     ...       5   1
# 2018-10-23  Dario Saric              F          37:42   5     ...       5   1
# 2018-10-24  Dario Saric              F          33:30   6     ...       0   0
#
#            BLK TO PF PTS PLUS_MINUS HOME_AWAY OPP_TEAM_ABBREVIATION  \
# Date
# 2018-10-16   0  3  5   6         -4      AWAY                   BOS
# 2018-10-18   0  3  2  13          9      HOME                   CHI
# 2018-10-20   1  2  3  13        -11      HOME                   ORL
# 2018-10-23   1  1  4  14          1      AWAY                   DET
# 2018-10-24   0  1  3  15        -16      AWAY                   MIL
#
#            OPP_TEAM_ID
# Date
# 2018-10-16  1610612738
# 2018-10-18  1610612741
# 2018-10-20  1610612753
# 2018-10-23  1610612765
# 2018-10-24  1610612749
#
# [5 rows x 31 columns]

# %%
finished = 1
total = len(dict_player_stats.keys())

for player_key in dict_player_stats.keys():
    df_player = nba_stats.get_player_stats()[player_key]
    df_player.OPP_TEAM_ABBREVIATION = df_player.apply(row_to_abb, axis=1)
    
    if finished % 5 == 0:
        print('updated player {} of {}'.format(finished, total))
    finished += 1
# Out:
# updated player 5 of 899
# updated player 10 of 899
# updated player 15 of 899
# updated player 20 of 899
# updated player 25 of 899
# updated player 30 of 899
# updated player 35 of 899
# updated player 40 of 899
# updated player 45 of 899
# updated player 50 of 899
# updated player 55 of 899
# updated player 60 of 899
# updated player 65 of 899
# updated player 70 of 899
# updated player 75 of 899
# updated player 80 of 899
# updated player 85 of 899
# updated player 90 of 899
# updated player 95 of 899
# updated player 100 of 899
# updated player 105 of 899
# updated player 110 of 899
# updated player 115 of 899
# updated player 120 of 899
# updated player 125 of 899
# updated player 130 of 899
# updated player 135 of 899
# updated player 140 of 899
# updated player 145 of 899
# updated player 150 of 899
# updated player 155 of 899
# updated player 160 of 899
# updated player 165 of 899
# updated player 170 of 899
# updated player 175 of 899
# updated player 180 of 899
# updated player 185 of 899
# updated player 190 of 899
# updated player 195 of 899
# updated player 200 of 899
# updated player 205 of 899
# updated player 210 of 899
# updated player 215 of 899
# updated player 220 of 899
# updated player 225 of 899
# updated player 230 of 899
# updated player 235 of 899
# updated player 240 of 899
# updated player 245 of 899
# updated player 250 of 899
# updated player 255 of 899
# updated player 260 of 899
# updated player 265 of 899
# updated player 270 of 899
# updated player 275 of 899
# updated player 280 of 899
# updated player 285 of 899
# updated player 290 of 899
# updated player 295 of 899
# updated player 300 of 899
# updated player 305 of 899
# updated player 310 of 899
# updated player 315 of 899
# updated player 320 of 899
# updated player 325 of 899
# updated player 330 of 899
# updated player 335 of 899
# updated player 340 of 899
# updated player 345 of 899
# updated player 350 of 899
# updated player 355 of 899
# updated player 360 of 899
# updated player 365 of 899
# updated player 370 of 899
# updated player 375 of 899
# updated player 380 of 899
# updated player 385 of 899
# updated player 390 of 899
# updated player 395 of 899
# updated player 400 of 899
# updated player 405 of 899
# updated player 410 of 899
# updated player 415 of 899
# updated player 420 of 899
# updated player 425 of 899
# updated player 430 of 899
# updated player 435 of 899
# updated player 440 of 899
# updated player 445 of 899
# updated player 450 of 899
# updated player 455 of 899
# updated player 460 of 899
# updated player 465 of 899
# updated player 470 of 899
# updated player 475 of 899
# updated player 480 of 899
# updated player 485 of 899
# updated player 490 of 899
# updated player 495 of 899
# updated player 500 of 899
# updated player 505 of 899
# updated player 510 of 899
# updated player 515 of 899
# updated player 520 of 899
# updated player 525 of 899
# updated player 530 of 899
# updated player 535 of 899
# updated player 540 of 899
# 2016-12-11  Dario Saric                         19:52   1     ...       2   0
# 2016-12-08  Dario Saric                         25:13   5     ...       1   0
# 2016-12-06  Dario Saric                         25:05   6     ...       0   1
# 2016-12-05  Dario Saric                         24:39   6     ...       0   1
# 2016-12-03  Dario Saric                         27:21   7     ...       2   1
# 2016-12-02  Dario Saric                         16:07   1     ...       0   0
# 2016-11-28  Dario Saric                         23:34   3     ...       4   0
# 2016-11-27  Dario Saric                         19:32   4     ...       3   0
#
#            BLK TO PF PTS PLUS_MINUS HOME_AWAY OPP_TEAM_ABBREVIATION  \
# Date
# 2018-10-16   0  3  5   6         -4      AWAY                   BOS
# 2018-10-18   0  3  2  13          9      HOME                   CHI
# 2018-10-20   1  2  3  13        -11      HOME                   ORL
# 2018-10-23   1  1  4  14          1      AWAY                   DET
# 2018-10-24   0  1  3  15        -16      AWAY                   MIL
# 2018-10-27   0  1  4  11          0      HOME                   CHA
# 2018-10-29   0  1  1   4         16      HOME                   ATL
# 2018-10-30   0  3  2   8         -6      AWAY                   TOR
# 2018-11-01   0  1  5   5         -4      HOME                   LAC
# 2018-11-03   0  2  3   5          2      HOME                   DET
# 2018-11-04   0  1  3  14         -9      AWAY                   BKN
# 2018-11-07   0  1  0  18         -1      AWAY                   IND
# 2018-11-09   1  5  4  18         -3      HOME                   CHA
# 2018-11-14   0  1  2   9          7      HOME                   NOP
# 2018-11-16   1  3  4   9          6      HOME                   POR
# 2017-11-03   0  1  2  15          4      HOME                   IND
# 2017-01-03   1  3  1   8          6      HOME                   MIN
# 2017-01-06   0  2  0   8          5      AWAY                   BOS
# 2017-01-08   0  4  2  18          5      AWAY                   BKN
# 2017-01-11   0  0  0   3        -16      HOME                   NYK
# 2017-01-13   0  4  0  15         -1      HOME                   CHA
# 2017-01-14   0  2  2   9         -7      AWAY                   WAS
# 2017-01-16   0  3  1  17         -9      AWAY                   MIL
# 2017-01-18   2  3  1   8          1      HOME                   TOR
# 2017-01-20   1  2  0   3        -13      HOME                   POR
# 2017-01-21   0  2  0   3        -21      AWAY                   ATL
# 2017-01-24   1  0  2  16         15      HOME                   LAC
# 2017-01-25   0  0  2  17         -6      AWAY                   MIL
# 2017-01-27   1  2  2  12          6      HOME                   HOU
# 2017-01-29   0  1  2   6        -32      AWAY                   CHI
# ...         .. .. ..  ..        ...       ...                   ...
# 2018-02-03   0  2  1  16         -1      AWAY                   IND
# 2018-02-02   0  3  3  17          5      HOME                   MIA
# 2018-01-31   0  1  1  12          3      AWAY                   BKN
# 2018-01-29   0  2  1  19        -13      AWAY                   MIL
# 2018-01-28   0  1  5  16         -2      AWAY                   OKC
# 2018-01-26   1  2  2  15         14      AWAY                   SAS
# 2018-01-24   0  2  0  21         31      HOME                   CHI
# 2018-01-22   1  4  2  22          6      AWAY                   MEM
# 2018-01-20   0  3  1  13          3      HOME                   MIL
# 2018-01-18   0  4  3  16         -1      AWAY                   BOS
# 2018-01-15   1  2  5  11         13      HOME                   TOR
# 2018-01-11   0  2  4  14        -10      HOME                   BOS
# 2018-01-05   0  1  0  11         24      HOME                   DET
# 2018-01-03   0  1  0  15         19      HOME                   SAS
# 2016-12-30   0  1  4  13          2      AWAY                   DEN
# 2016-12-29   1  2  1  14        -13      AWAY                   UTA
# 2016-12-26   0  1  1  12          4      AWAY                   SAC
# 2016-12-23   0  1  3   8        -10      AWAY                   PHX
# 2016-12-20   0  1  0   2          1      HOME                   NOP
# 2016-12-18   0  1  1   7         17      HOME                   BKN
# 2016-12-16   0  1  1   7          1      HOME                   LAL
# 2016-12-14   0  1  5   2          5      HOME                   TOR
# 2016-12-11   0  2  0   4          3      AWAY                   DET
# 2016-12-08   1  1  2  13         10      AWAY                   NOP
# 2016-12-06   0  2  4  17        -11      AWAY                   MEM
# 2016-12-05   0  2  2  17        -15      HOME                   DEN
# 2016-12-03   0  3  0  21        -12      HOME                   BOS
# 2016-12-02   0  2  0   2        -17      HOME                   ORL
# 2016-11-28   1  2  1   8        -16      AWAY                   TOR
# 2016-11-27   1  4  3  10         -8      HOME                   CLE
#
#            OPP_TEAM_ID
# Date
# 2018-10-16  1610612738
# 2018-10-18  1610612741
# 2018-10-20  1610612753
# 2018-10-23  1610612765
# 2018-10-24  1610612749
# 2018-10-27  1610612766
# 2018-10-29  1610612737
# 2018-10-30  1610612761
# 2018-11-01  1610612746
# 2018-11-03  1610612765
# 2018-11-04  1610612751
# 2018-11-07  1610612754
# 2018-11-09  1610612766
# 2018-11-14  1610612740
# 2018-11-16  1610612757
# 2017-11-03  1610612754
# 2017-01-03  1610612750
# 2017-01-06  1610612738
# 2017-01-08  1610612751
# 2017-01-11  1610612752
# 2017-01-13  1610612766
# 2017-01-14  1610612764
# 2017-01-16  1610612749
# 2017-01-18  1610612761
# 2017-01-20  1610612757
# 2017-01-21  1610612737
# 2017-01-24  1610612746
# 2017-01-25  1610612749
# 2017-01-27  1610612745
# 2017-01-29  1610612741
# ...                ...
# 2018-02-03  1610612754
# 2018-02-02  1610612748
# 2018-01-31  1610612751
# 2018-01-29  1610612749
# 2018-01-28  1610612760
# 2018-01-26  1610612759
# 2018-01-24  1610612741
# 2018-01-22  1610612763
# 2018-01-20  1610612749
# 2018-01-18  1610612738
# 2018-01-15  1610612761
# 2018-01-11  1610612738
# 2018-01-05  1610612765
# 2018-01-03  1610612759
# 2016-12-30  1610612743
# 2016-12-29  1610612762
# 2016-12-26  1610612758
# 2016-12-23  1610612756
# 2016-12-20  1610612740
# 2016-12-18  1610612751
# 2016-12-16  1610612747
# 2016-12-14  1610612761
# 2016-12-11  1610612765
# 2016-12-08  1610612740
# 2016-12-06  1610612763
# 2016-12-05  1610612743
# 2016-12-03  1610612738
# 2016-12-02  1610612753
# 2016-11-28  1610612761
# 2016-11-27  1610612739
#
# [197 rows x 31 columns]

# %% [markdown]
# # Resave new version

# %%
import pickle
import os

file_directory = os.path.join(parent_dir, 'Data', 'nba_stats.pickle')
pickle.dump(nba_stats, open(file_directory, 'wb'))
